# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from spectral import open_image
import scipy.io as sio
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix

# %% [markdown]
# ## Coordinate Attention Block:

# %%
class CoordinateAttention(nn.Module):
    def __init__(self, in_channels, reduction=32):
        super(CoordinateAttention, self).__init__()

        # Adaptive average pooling along the height and width dimensions
        self.pool_h = nn.AdaptiveAvgPool2d((None, 1))  # Horizontal pooling
        self.pool_w = nn.AdaptiveAvgPool2d((1, None))  # Vertical pooling

        # Calculation of reduced channels based on the reduction ratio
        reduced_channels = max(8, in_channels // reduction)
        
        # Bottleneck layers for attention mechanism
        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, stride=1, padding=0)
        self.bn = nn.BatchNorm2d(reduced_channels)
        self.act = nn.ReLU()
        
        # Separate convolution layers for horizontal and vertical attention
        self.conv_h = nn.Conv2d(reduced_channels, in_channels, kernel_size=1, stride=1, padding=0)
        self.conv_w = nn.Conv2d(reduced_channels, in_channels, kernel_size=1, stride=1, padding=0)

    def forward(self, x):
        b, c, h, w = x.size()  # Get the batch size and input dimensions
        
        # Pool along height and width axes separately
        h_pool = self.pool_h(x).permute(0, 1, 3, 2)
        w_pool = self.pool_w(x)
        
        # Concatenate pooled features and pass through a bottleneck
        y = torch.cat([h_pool, w_pool], dim=-1)
        y = self.act(self.bn(self.conv1(y)))
        
        # Split into horizontal and vertical attention maps
        h_attention, w_attention = y.split([h, w], dim=-1)
        
        # Apply conv layers to generate attention maps and repermute
        h_attention = self.conv_h(h_attention.permute(0, 1, 3, 2))
        w_attention = self.conv_w(w_attention)
        
        # Return input modulated by both horizontal and vertical attention
        return x * h_attention.sigmoid() * w_attention.sigmoid()

# %% [markdown]
# ## Multi-Scale Fusion Block:

# %%
class MultiScaleFusion(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(MultiScaleFusion, self).__init__()
        # Convolutions with different kernel sizes
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        self.conv3 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(in_channels, out_channels, kernel_size=5, padding=2)
        
        # Fusion convolution layer to combine multi-scale features
        self.fusion_conv = nn.Conv2d(out_channels * 3, out_channels, kernel_size=1)
        
    def forward(self, x):
        # Apply convolution at different scales
        x1 = self.conv1(x)
        x3 = self.conv3(x)
        x5 = self.conv5(x)
        
        # Concatenate feature maps from different scales
        x_fused = torch.cat([x1, x3, x5], dim=1)
        return self.fusion_conv(x_fused)

# %% [markdown]
# ## Main Model for Hyperspectral Image Classification:

# %%
class HyperspectralClassificationModel(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(HyperspectralClassificationModel, self).__init__()
        
        # Apply multi-scale feature extraction
        self.multi_scale_fusion = MultiScaleFusion(in_channels, 64)  # Use dynamic input channels
        
        # Apply coordinate attention
        self.coord_attention = CoordinateAttention(64)
        
        # Fully connected layer for classification, adjust based on pooling size
        self.fc = nn.Linear(64 * 16 * 16, num_classes)  # Adjust based on pooling output
    
    def forward(self, x):
        # Multi-scale fusion
        x = self.multi_scale_fusion(x)
        
        # Coordinate attention
        x = self.coord_attention(x)
        
        # Pool and flatten before the final fully connected layer
        x = F.adaptive_avg_pool2d(x, (16, 16))
        x = torch.flatten(x, 1)
        
        # Final classification
        return self.fc(x)

# %%
# Custom Dataset for Hyperspectral Images with Patches
class HyperspectralDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        patch = self.data[idx]
        label = self.labels[idx]
        return torch.tensor(patch, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# Function to extract patches from hyperspectral images
def extract_patches(img, labels, patch_size):
    margin = patch_size // 2
    img_padded = np.pad(img, [(margin, margin), (margin, margin), (0, 0)], mode='constant')
    
    patches, patch_labels = [], []
    for i in range(margin, img.shape[0] - margin):
        for j in range(margin, img.shape[1] - margin):
            if labels[i, j] != 0:  # Exclude background
                patch = img_padded[i-margin:i+margin+1, j-margin:j+margin+1, :]
                patches.append(patch)
                patch_labels.append(labels[i, j] - 1)  # Convert to zero-based index
    return np.array(patches), np.array(patch_labels)

# %% [markdown]
# ## Function to calculate metrics:

# %%
def calculate_metrics(y_true, y_pred, num_classes):
    cm = confusion_matrix(y_true, y_pred, labels=range(num_classes))
    OA = accuracy_score(y_true, y_pred)
    class_acc = cm.diagonal() / cm.sum(axis=1)
    class_acc[np.isnan(class_acc)] = 0  # Handle divide by zero for empty classes
    AA = np.mean(class_acc)
    Kappa = cohen_kappa_score(y_true, y_pred)
    return {"OA": OA, "AA": AA, "Kappa": Kappa}

# %% [markdown]
# ## Loading the Pavia University dataset and split into train, validation, and test sets:

# %%
def load_pavia_data_with_splits(patch_size, num_classes):
    # Load the Pavia University dataset
    data = sio.loadmat('PaviaU.mat')['paviaU']
    labels = sio.loadmat('PaviaU_gt.mat')['paviaU_gt']
    
    # Extract patches
    patches, patch_labels = extract_patches(data, labels, patch_size)
    
    # Initialize arrays for train, validation, and test splits
    X_train, y_train = [], []
    X_val, y_val = [], []
    X_test, y_test = [], []
    
    # Split data class-wise
    for class_label in np.unique(patch_labels):
        class_indices = np.where(patch_labels == class_label)[0]
        np.random.shuffle(class_indices)
        
        # Take 300 samples for training, 300 for validation, remaining for testing
        train_indices = class_indices[:300]
        val_indices = class_indices[300:600]
        test_indices = class_indices[600:]
        
        X_train.extend(patches[train_indices])
        y_train.extend(patch_labels[train_indices])
        
        X_val.extend(patches[val_indices])
        y_val.extend(patch_labels[val_indices])
        
        X_test.extend(patches[test_indices])
        y_test.extend(patch_labels[test_indices])
    
    # Convert to numpy arrays
    X_train, y_train = np.array(X_train), np.array(y_train)
    X_val, y_val = np.array(X_val), np.array(y_val)
    X_test, y_test = np.array(X_test), np.array(y_test)
    
    # Create datasets and dataloaders
    train_dataset = HyperspectralDataset(X_train, y_train)
    val_dataset = HyperspectralDataset(X_val, y_val)
    test_dataset = HyperspectralDataset(X_test, y_test)
    
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
    
    return train_loader, val_loader, test_loader, y_test

# %% [markdown]
# ## Visualizing the Dataset:

# %%
# Load the .mat file
pavia_data = sio.loadmat('PaviaU.mat')

# Print all the keys in the file
print(pavia_data.keys())

# Check the type and shape of the 'paviaU' data
paviaU = pavia_data['paviaU']
print(f"Type of 'paviaU': {type(paviaU)}")
print(f"Shape of 'paviaU': {paviaU.shape}")
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'paviaU'])
# Type of 'paviaU': <class 'numpy.ndarray'>
# Shape of 'paviaU': (610, 340, 103)

# %%
import matplotlib.pyplot as plt

# Display the first spectral band (band 1) of Pavia University
plt.imshow(paviaU[:, :, 0], cmap='gray')
plt.title('Pavia University - Band 1')
plt.show()

# %%
import scipy.io as sio

# Load the ground truth .mat file
pavia_gt_data = sio.loadmat('PaviaU_gt.mat')

# Print all the keys in the file to see available variables
print(pavia_gt_data.keys())

# Assuming the ground truth key is 'paviaU_gt' (or modify if the key is different)
if 'paviaU_gt' in pavia_gt_data:
    paviaU_gt = pavia_gt_data['paviaU_gt']
    print(f"Type of 'paviaU_gt': {type(paviaU_gt)}")
    print(f"Shape of 'paviaU_gt': {paviaU_gt.shape}")
else:
    print("Key 'paviaU_gt' not found. Check the keys in the ground truth file.")
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'paviaU_gt'])
# Type of 'paviaU_gt': <class 'numpy.ndarray'>
# Shape of 'paviaU_gt': (610, 340)

# %%
import matplotlib.pyplot as plt

# Display the ground truth for Pavia University
plt.imshow(paviaU_gt, cmap='nipy_spectral')  # Use a colormap suitable for categorical data
plt.colorbar()  # Show a color bar to indicate class labels
plt.title('Pavia University Ground Truth')
plt.show()

# %% [markdown]
# ## Training the Model:

# %%
def train_model(train_loader, val_loader, in_channels, num_classes, epochs=20, lr=0.001):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    model = HyperspectralClassificationModel(in_channels=in_channels, num_classes=num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = torch.nn.CrossEntropyLoss()

    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.permute(0, 3, 1, 2).to(device), labels.to(device)  # [B, C, H, W]
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        train_losses.append(running_loss / len(train_loader))
        
        # Validation step
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.permute(0, 3, 1, 2).to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()        
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        val_losses.append(val_loss / len(val_loader))
        
        val_accuracy = correct / total
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Val Accuracy: {val_accuracy:.4f}")
    
    return model

# %% [markdown]
# ## Testing the model and calculating metrics:

# %%
def test_model(model, test_loader, y_test, num_classes):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    
    y_pred = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.permute(0, 3, 1, 2).to(device)  # [B, C, H, W]
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            y_pred.extend(predicted.cpu().numpy())

    metrics = calculate_metrics(y_test, y_pred, num_classes)
    return metrics

# Main script to evaluate different window sizes
if __name__ == "__main__":
    window_sizes = [11, 12, 13]  # List of window sizes
    num_classes = 9  # Pavia have 9 classes
    in_channels = 103  # Pavia University has 103 spectral bands
    
    for window_size in window_sizes:
        print(f"Evaluating window size: {window_size}x{window_size}")
        
        # Load data with splits for training (300), validation (300), and remaining test set
        train_loader, val_loader, test_loader, y_test = load_pavia_data_with_splits(window_size, num_classes)
        
        # Train the model
        model = train_model(train_loader, val_loader, in_channels=in_channels, num_classes=num_classes, epochs=100, lr=3e-4)
        
        # Test the model and get metrics
        metrics = test_model(model, test_loader, y_test, num_classes)
        
        print(f"Metrics for window size {window_size}x{window_size}: {metrics}")
# Out:
# Evaluating window size: 11x11
# Epoch [1/100], Train Loss: 143.9427, Val Loss: 22.8900, Val Accuracy: 0.6163
# Epoch [2/100], Train Loss: 14.4328, Val Loss: 7.3687, Val Accuracy: 0.7874
# Epoch [3/100], Train Loss: 7.0954, Val Loss: 12.2638, Val Accuracy: 0.6833
# Epoch [4/100], Train Loss: 8.4444, Val Loss: 19.8512, Val Accuracy: 0.5785
# Epoch [5/100], Train Loss: 9.7175, Val Loss: 13.0134, Val Accuracy: 0.7300
# Epoch [6/100], Train Loss: 5.4785, Val Loss: 16.5990, Val Accuracy: 0.6233
# Epoch [7/100], Train Loss: 17.2450, Val Loss: 30.0742, Val Accuracy: 0.6296
# Epoch [8/100], Train Loss: 63.2136, Val Loss: 60.2049, Val Accuracy: 0.6619
# Epoch [9/100], Train Loss: 44.8351, Val Loss: 22.3118, Val Accuracy: 0.7811
# Epoch [10/100], Train Loss: 16.8674, Val Loss: 26.2425, Val Accuracy: 0.7278
# Epoch [11/100], Train Loss: 10.0099, Val Loss: 14.1082, Val Accuracy: 0.7685
# Epoch [12/100], Train Loss: 11.2441, Val Loss: 17.4949, Val Accuracy: 0.7693
# Epoch [13/100], Train Loss: 6.0903, Val Loss: 17.6958, Val Accuracy: 0.7659
# Epoch [14/100], Train Loss: 10.3125, Val Loss: 11.9713, Val Accuracy: 0.8193
# Epoch [15/100], Train Loss: 7.2352, Val Loss: 18.8514, Val Accuracy: 0.7570
# Epoch [16/100], Train Loss: 10.1287, Val Loss: 18.7817, Val Accuracy: 0.7659
# Epoch [17/100], Train Loss: 7.0006, Val Loss: 20.1420, Val Accuracy: 0.7719
# Epoch [18/100], Train Loss: 7.8158, Val Loss: 16.9591, Val Accuracy: 0.7741
# Epoch [19/100], Train Loss: 6.1408, Val Loss: 11.2800, Val Accuracy: 0.8600
# Epoch [20/100], Train Loss: 6.7329, Val Loss: 28.7829, Val Accuracy: 0.7222
# Epoch [21/100], Train Loss: 8.6327, Val Loss: 16.3543, Val Accuracy: 0.7959
# Epoch [22/100], Train Loss: 28.8982, Val Loss: 64.8153, Val Accuracy: 0.6715
# Epoch [23/100], Train Loss: 30.4758, Val Loss: 91.3467, Val Accuracy: 0.6070
# Epoch [24/100], Train Loss: 21.6176, Val Loss: 69.5011, Val Accuracy: 0.7178
# Epoch [25/100], Train Loss: 10.7280, Val Loss: 23.4957, Val Accuracy: 0.7759
# Epoch [26/100], Train Loss: 7.5948, Val Loss: 30.7316, Val Accuracy: 0.7437
# Epoch [27/100], Train Loss: 8.9323, Val Loss: 48.8692, Val Accuracy: 0.7096
# Epoch [28/100], Train Loss: 12.5236, Val Loss: 30.8736, Val Accuracy: 0.7959
# Epoch [29/100], Train Loss: 11.6217, Val Loss: 12.4539, Val Accuracy: 0.8822
# Epoch [30/100], Train Loss: 5.8004, Val Loss: 15.1969, Val Accuracy: 0.8389
# Epoch [31/100], Train Loss: 2.7523, Val Loss: 13.5518, Val Accuracy: 0.8770
# Epoch [32/100], Train Loss: 1.3703, Val Loss: 10.5847, Val Accuracy: 0.9004
# Epoch [33/100], Train Loss: 1.2039, Val Loss: 14.7519, Val Accuracy: 0.8515
# Epoch [34/100], Train Loss: 2.6792, Val Loss: 21.6615, Val Accuracy: 0.8056
# Epoch [35/100], Train Loss: 3.4683, Val Loss: 21.2619, Val Accuracy: 0.7956
# Epoch [36/100], Train Loss: 9.6884, Val Loss: 108.1432, Val Accuracy: 0.6078
# Epoch [37/100], Train Loss: 16.0473, Val Loss: 44.8031, Val Accuracy: 0.7559
# Epoch [38/100], Train Loss: 19.5034, Val Loss: 47.8601, Val Accuracy: 0.7548
# Epoch [39/100], Train Loss: 22.5635, Val Loss: 32.8167, Val Accuracy: 0.8137
# Epoch [40/100], Train Loss: 13.2258, Val Loss: 45.0300, Val Accuracy: 0.8085
# Epoch [41/100], Train Loss: 14.0982, Val Loss: 29.0514, Val Accuracy: 0.8178
# Epoch [42/100], Train Loss: 5.1497, Val Loss: 16.9394, Val Accuracy: 0.8730
# Epoch [43/100], Train Loss: 76.2548, Val Loss: 143.4214, Val Accuracy: 0.7293
# Epoch [44/100], Train Loss: 40.0210, Val Loss: 97.8423, Val Accuracy: 0.6981
# Epoch [45/100], Train Loss: 31.9789, Val Loss: 57.8471, Val Accuracy: 0.8341
# Epoch [46/100], Train Loss: 18.5174, Val Loss: 70.4503, Val Accuracy: 0.7426
# Epoch [47/100], Train Loss: 13.0283, Val Loss: 23.9550, Val Accuracy: 0.8948
# Epoch [48/100], Train Loss: 3.2489, Val Loss: 36.0568, Val Accuracy: 0.8381
# Epoch [49/100], Train Loss: 3.2857, Val Loss: 23.6602, Val Accuracy: 0.8822
# Epoch [50/100], Train Loss: 2.3892, Val Loss: 34.5974, Val Accuracy: 0.8485
# Epoch [51/100], Train Loss: 5.4520, Val Loss: 64.5161, Val Accuracy: 0.7659
# Epoch [52/100], Train Loss: 4.2319, Val Loss: 42.8111, Val Accuracy: 0.8259
# Epoch [53/100], Train Loss: 2.2840, Val Loss: 20.5234, Val Accuracy: 0.9007
# Epoch [54/100], Train Loss: 4.0312, Val Loss: 35.0196, Val Accuracy: 0.8270
# Epoch [55/100], Train Loss: 2.0821, Val Loss: 46.7301, Val Accuracy: 0.8170
# Epoch [56/100], Train Loss: 1.5670, Val Loss: 21.9003, Val Accuracy: 0.8959
# Epoch [57/100], Train Loss: 1.1110, Val Loss: 23.9522, Val Accuracy: 0.8922
# Epoch [58/100], Train Loss: 1.3396, Val Loss: 22.7106, Val Accuracy: 0.8859
# Epoch [59/100], Train Loss: 1.8520, Val Loss: 73.4873, Val Accuracy: 0.7585
# Epoch [60/100], Train Loss: 2.0062, Val Loss: 22.8021, Val Accuracy: 0.8663
# Epoch [61/100], Train Loss: 4.4831, Val Loss: 25.9949, Val Accuracy: 0.8759
# Epoch [62/100], Train Loss: 3.5708, Val Loss: 64.4093, Val Accuracy: 0.7548
# Epoch [63/100], Train Loss: 2.3382, Val Loss: 27.0975, Val Accuracy: 0.8748
# Epoch [64/100], Train Loss: 1.6348, Val Loss: 55.6163, Val Accuracy: 0.7789
# Epoch [65/100], Train Loss: 6.3016, Val Loss: 30.8171, Val Accuracy: 0.8704
# Epoch [66/100], Train Loss: 10.5861, Val Loss: 27.0138, Val Accuracy: 0.8730
# Epoch [67/100], Train Loss: 3.2771, Val Loss: 39.6110, Val Accuracy: 0.8359
# Epoch [68/100], Train Loss: 2.4374, Val Loss: 21.5812, Val Accuracy: 0.8756
# Epoch [69/100], Train Loss: 3.6585, Val Loss: 42.6293, Val Accuracy: 0.8400
# Epoch [70/100], Train Loss: 3.7812, Val Loss: 33.2004, Val Accuracy: 0.8778
# Epoch [71/100], Train Loss: 5.6577, Val Loss: 56.3943, Val Accuracy: 0.8126
# Epoch [72/100], Train Loss: 12.3375, Val Loss: 40.0384, Val Accuracy: 0.8674
# Epoch [73/100], Train Loss: 5.0140, Val Loss: 95.4745, Val Accuracy: 0.7281
# Epoch [74/100], Train Loss: 6.2085, Val Loss: 52.4870, Val Accuracy: 0.7811
# Epoch [75/100], Train Loss: 8.5290, Val Loss: 67.9104, Val Accuracy: 0.7737
# Epoch [76/100], Train Loss: 7.5186, Val Loss: 55.7198, Val Accuracy: 0.7996
# Epoch [77/100], Train Loss: 18.2476, Val Loss: 71.3896, Val Accuracy: 0.8185
# Epoch [78/100], Train Loss: 15.6537, Val Loss: 93.8037, Val Accuracy: 0.7389
# Epoch [79/100], Train Loss: 10.5170, Val Loss: 81.3522, Val Accuracy: 0.8226
# Epoch [80/100], Train Loss: 6.2950, Val Loss: 64.8638, Val Accuracy: 0.8289
# Epoch [81/100], Train Loss: 5.3761, Val Loss: 100.3301, Val Accuracy: 0.7456
# Epoch [82/100], Train Loss: 2.4668, Val Loss: 45.7991, Val Accuracy: 0.8237
# Epoch [83/100], Train Loss: 6.6981, Val Loss: 47.2075, Val Accuracy: 0.8563
# Epoch [84/100], Train Loss: 1.9584, Val Loss: 60.5548, Val Accuracy: 0.7963
# Epoch [85/100], Train Loss: 1.2036, Val Loss: 56.1279, Val Accuracy: 0.8319
# Epoch [86/100], Train Loss: 1.5290, Val Loss: 28.8405, Val Accuracy: 0.8867
# Epoch [87/100], Train Loss: 1.2539, Val Loss: 32.1590, Val Accuracy: 0.8967
# Epoch [88/100], Train Loss: 1.1719, Val Loss: 45.3521, Val Accuracy: 0.8407
# Epoch [89/100], Train Loss: 1.7705, Val Loss: 67.0014, Val Accuracy: 0.8019
# Epoch [90/100], Train Loss: 1.1507, Val Loss: 36.1042, Val Accuracy: 0.8711
# Epoch [91/100], Train Loss: 1.1404, Val Loss: 62.5033, Val Accuracy: 0.7933
# Epoch [92/100], Train Loss: 4.1765, Val Loss: 36.2520, Val Accuracy: 0.8848
# Epoch [93/100], Train Loss: 3.5300, Val Loss: 68.6357, Val Accuracy: 0.7933
# Epoch [94/100], Train Loss: 19.2979, Val Loss: 41.3593, Val Accuracy: 0.8619
# Epoch [95/100], Train Loss: 55.0156, Val Loss: 58.2681, Val Accuracy: 0.8630
# Epoch [96/100], Train Loss: 37.2611, Val Loss: 97.5380, Val Accuracy: 0.8315
# Epoch [97/100], Train Loss: 8.6667, Val Loss: 45.0230, Val Accuracy: 0.8759
# Epoch [98/100], Train Loss: 7.3119, Val Loss: 52.5074, Val Accuracy: 0.8600
# Epoch [99/100], Train Loss: 1.6783, Val Loss: 30.8580, Val Accuracy: 0.9144
# Epoch [100/100], Train Loss: 1.9490, Val Loss: 36.5215, Val Accuracy: 0.8937
# Metrics for window size 11x11: {'OA': 0.8867272311735802, 'AA': 0.893312457545075, 'Kappa': 0.8452166014962783}
# Evaluating window size: 12x12
# Epoch [1/100], Train Loss: 144.2143, Val Loss: 22.6290, Val Accuracy: 0.6611
# Epoch [2/100], Train Loss: 18.1113, Val Loss: 16.5722, Val Accuracy: 0.6611
# Epoch [3/100], Train Loss: 9.5905, Val Loss: 8.2121, Val Accuracy: 0.7159
# Epoch [4/100], Train Loss: 6.7853, Val Loss: 5.8244, Val Accuracy: 0.7537
# Epoch [5/100], Train Loss: 6.0290, Val Loss: 11.3876, Val Accuracy: 0.7007
# Epoch [6/100], Train Loss: 11.1698, Val Loss: 15.4637, Val Accuracy: 0.6919
# Epoch [7/100], Train Loss: 19.8801, Val Loss: 107.6626, Val Accuracy: 0.4396
# Epoch [8/100], Train Loss: 50.3420, Val Loss: 37.8397, Val Accuracy: 0.6978
# Epoch [9/100], Train Loss: 19.2830, Val Loss: 25.9457, Val Accuracy: 0.7433
# Epoch [10/100], Train Loss: 10.2076, Val Loss: 22.0194, Val Accuracy: 0.7281
# Epoch [11/100], Train Loss: 8.6717, Val Loss: 18.2519, Val Accuracy: 0.7700
# Epoch [12/100], Train Loss: 7.5716, Val Loss: 20.8732, Val Accuracy: 0.7430
# Epoch [13/100], Train Loss: 10.2701, Val Loss: 23.9393, Val Accuracy: 0.7530
# Epoch [14/100], Train Loss: 9.0990, Val Loss: 12.5840, Val Accuracy: 0.8178
# Epoch [15/100], Train Loss: 5.7465, Val Loss: 19.3504, Val Accuracy: 0.7889
# Epoch [16/100], Train Loss: 4.9556, Val Loss: 7.4228, Val Accuracy: 0.8578
# Epoch [17/100], Train Loss: 13.7495, Val Loss: 21.5054, Val Accuracy: 0.7756
# Epoch [18/100], Train Loss: 21.1919, Val Loss: 51.3763, Val Accuracy: 0.6967
# Epoch [19/100], Train Loss: 31.6685, Val Loss: 91.9588, Val Accuracy: 0.6052
# Epoch [20/100], Train Loss: 18.3476, Val Loss: 24.0986, Val Accuracy: 0.8148
# Epoch [21/100], Train Loss: 8.1661, Val Loss: 28.5137, Val Accuracy: 0.7896
# Epoch [22/100], Train Loss: 4.7780, Val Loss: 33.4242, Val Accuracy: 0.7463
# Epoch [23/100], Train Loss: 5.0034, Val Loss: 28.6367, Val Accuracy: 0.7996
# Epoch [24/100], Train Loss: 5.1989, Val Loss: 22.0411, Val Accuracy: 0.7915
# Epoch [25/100], Train Loss: 3.9751, Val Loss: 28.7779, Val Accuracy: 0.7744
# Epoch [26/100], Train Loss: 12.5005, Val Loss: 53.4389, Val Accuracy: 0.7004
# Epoch [27/100], Train Loss: 18.4257, Val Loss: 23.0508, Val Accuracy: 0.8015
# Epoch [28/100], Train Loss: 15.7082, Val Loss: 53.5866, Val Accuracy: 0.7400
# Epoch [29/100], Train Loss: 16.5111, Val Loss: 24.2127, Val Accuracy: 0.8256
# Epoch [30/100], Train Loss: 12.1964, Val Loss: 104.9964, Val Accuracy: 0.6685
# Epoch [31/100], Train Loss: 13.8887, Val Loss: 21.0352, Val Accuracy: 0.8319
# Epoch [32/100], Train Loss: 5.7986, Val Loss: 32.0505, Val Accuracy: 0.7759
# Epoch [33/100], Train Loss: 4.5262, Val Loss: 12.2370, Val Accuracy: 0.8856
# Epoch [34/100], Train Loss: 6.9342, Val Loss: 26.8129, Val Accuracy: 0.8407
# Epoch [35/100], Train Loss: 7.0788, Val Loss: 23.4668, Val Accuracy: 0.8178
# Epoch [36/100], Train Loss: 4.7655, Val Loss: 27.6407, Val Accuracy: 0.8030
# Epoch [37/100], Train Loss: 6.3922, Val Loss: 27.8469, Val Accuracy: 0.8111
# Epoch [38/100], Train Loss: 3.1964, Val Loss: 63.5798, Val Accuracy: 0.7185
# Epoch [39/100], Train Loss: 3.7128, Val Loss: 88.2352, Val Accuracy: 0.7093
# Epoch [40/100], Train Loss: 9.3937, Val Loss: 19.1187, Val Accuracy: 0.8593
# Epoch [41/100], Train Loss: 22.9532, Val Loss: 57.6233, Val Accuracy: 0.7526
# Epoch [42/100], Train Loss: 132.0761, Val Loss: 201.5402, Val Accuracy: 0.6996
# Epoch [43/100], Train Loss: 34.1074, Val Loss: 36.0758, Val Accuracy: 0.8563
# Epoch [44/100], Train Loss: 6.7796, Val Loss: 34.7704, Val Accuracy: 0.8530
# Epoch [45/100], Train Loss: 5.2590, Val Loss: 73.6893, Val Accuracy: 0.7659
# Epoch [46/100], Train Loss: 4.3036, Val Loss: 17.8693, Val Accuracy: 0.9167
# Epoch [47/100], Train Loss: 1.7440, Val Loss: 22.5528, Val Accuracy: 0.8807
# Epoch [48/100], Train Loss: 2.0263, Val Loss: 13.9017, Val Accuracy: 0.9119
# Epoch [49/100], Train Loss: 3.5262, Val Loss: 29.0701, Val Accuracy: 0.8585
# Epoch [50/100], Train Loss: 3.0924, Val Loss: 44.5926, Val Accuracy: 0.7874
# Epoch [51/100], Train Loss: 2.2475, Val Loss: 49.4583, Val Accuracy: 0.8167
# Epoch [52/100], Train Loss: 30.7019, Val Loss: 68.0240, Val Accuracy: 0.8244
# Epoch [53/100], Train Loss: 16.2188, Val Loss: 44.8158, Val Accuracy: 0.8341
# Epoch [54/100], Train Loss: 4.7243, Val Loss: 23.0581, Val Accuracy: 0.8989
# Epoch [55/100], Train Loss: 6.0299, Val Loss: 26.8781, Val Accuracy: 0.8841
# Epoch [56/100], Train Loss: 2.8215, Val Loss: 22.3681, Val Accuracy: 0.8856
# Epoch [57/100], Train Loss: 3.1029, Val Loss: 30.0126, Val Accuracy: 0.8630
# Epoch [58/100], Train Loss: 1.9262, Val Loss: 26.8128, Val Accuracy: 0.8774
# Epoch [59/100], Train Loss: 1.8223, Val Loss: 46.0611, Val Accuracy: 0.8333
# Epoch [60/100], Train Loss: 2.8902, Val Loss: 99.2667, Val Accuracy: 0.7478
# Epoch [61/100], Train Loss: 1.7596, Val Loss: 16.6590, Val Accuracy: 0.9178
# Epoch [62/100], Train Loss: 1.1544, Val Loss: 17.7574, Val Accuracy: 0.9048
# Epoch [63/100], Train Loss: 4.2297, Val Loss: 52.5662, Val Accuracy: 0.8374
# Epoch [64/100], Train Loss: 15.9183, Val Loss: 50.3016, Val Accuracy: 0.8348
# Epoch [65/100], Train Loss: 6.3031, Val Loss: 19.9239, Val Accuracy: 0.8911
# Epoch [66/100], Train Loss: 6.8234, Val Loss: 41.9011, Val Accuracy: 0.8441
# Epoch [67/100], Train Loss: 2.1378, Val Loss: 70.2532, Val Accuracy: 0.7885
# Epoch [68/100], Train Loss: 1.9003, Val Loss: 19.5885, Val Accuracy: 0.8793
# Epoch [69/100], Train Loss: 2.1610, Val Loss: 35.5234, Val Accuracy: 0.8511
# Epoch [70/100], Train Loss: 2.4053, Val Loss: 26.7878, Val Accuracy: 0.8752
# Epoch [71/100], Train Loss: 2.8127, Val Loss: 59.3180, Val Accuracy: 0.7800
# Epoch [72/100], Train Loss: 11.4052, Val Loss: 33.9344, Val Accuracy: 0.8630
# Epoch [73/100], Train Loss: 5.5290, Val Loss: 19.4121, Val Accuracy: 0.9085
# Epoch [74/100], Train Loss: 4.3570, Val Loss: 20.1243, Val Accuracy: 0.9033
# Epoch [75/100], Train Loss: 2.7550, Val Loss: 84.7861, Val Accuracy: 0.7411
# Epoch [76/100], Train Loss: 4.8426, Val Loss: 23.3655, Val Accuracy: 0.9030
# Epoch [77/100], Train Loss: 2.5328, Val Loss: 27.1264, Val Accuracy: 0.8711
# Epoch [78/100], Train Loss: 7.5815, Val Loss: 93.5427, Val Accuracy: 0.7067
# Epoch [79/100], Train Loss: 6.8519, Val Loss: 30.7400, Val Accuracy: 0.8752
# Epoch [80/100], Train Loss: 3.3291, Val Loss: 34.0036, Val Accuracy: 0.8515
# Epoch [81/100], Train Loss: 7.7495, Val Loss: 61.9254, Val Accuracy: 0.8256
# Epoch [82/100], Train Loss: 14.6553, Val Loss: 68.0556, Val Accuracy: 0.8081
# Epoch [83/100], Train Loss: 9.6962, Val Loss: 29.5490, Val Accuracy: 0.8730
# Epoch [84/100], Train Loss: 14.9024, Val Loss: 187.9267, Val Accuracy: 0.6719
# Epoch [85/100], Train Loss: 9.3635, Val Loss: 29.1024, Val Accuracy: 0.8978
# Epoch [86/100], Train Loss: 4.9645, Val Loss: 177.8992, Val Accuracy: 0.6674
# Epoch [87/100], Train Loss: 2.7716, Val Loss: 35.4516, Val Accuracy: 0.8696
# Epoch [88/100], Train Loss: 11.3124, Val Loss: 39.5648, Val Accuracy: 0.8837
# Epoch [89/100], Train Loss: 5.6068, Val Loss: 92.8654, Val Accuracy: 0.7826
# Epoch [90/100], Train Loss: 3.9811, Val Loss: 39.2388, Val Accuracy: 0.8737
# Epoch [91/100], Train Loss: 5.4594, Val Loss: 27.1078, Val Accuracy: 0.9026
# Epoch [92/100], Train Loss: 4.3393, Val Loss: 22.8808, Val Accuracy: 0.9004
# Epoch [93/100], Train Loss: 6.2438, Val Loss: 88.6096, Val Accuracy: 0.7930
# Epoch [94/100], Train Loss: 2.7192, Val Loss: 20.6590, Val Accuracy: 0.9081
# Epoch [95/100], Train Loss: 0.8523, Val Loss: 20.9772, Val Accuracy: 0.9204
# Epoch [96/100], Train Loss: 0.6450, Val Loss: 19.6110, Val Accuracy: 0.8952
# Epoch [97/100], Train Loss: 0.6765, Val Loss: 17.9053, Val Accuracy: 0.9148
# Epoch [98/100], Train Loss: 1.5738, Val Loss: 79.9194, Val Accuracy: 0.7619
# Epoch [99/100], Train Loss: 0.9735, Val Loss: 16.2837, Val Accuracy: 0.9263
# Epoch [100/100], Train Loss: 0.2210, Val Loss: 16.9834, Val Accuracy: 0.9259
# Metrics for window size 12x12: {'OA': 0.9270015925872304, 'AA': 0.9280438267668836, 'Kappa': 0.9012219008210112}
# Evaluating window size: 13x13
# Epoch [1/100], Train Loss: 141.5802, Val Loss: 24.0781, Val Accuracy: 0.6533
# Epoch [2/100], Train Loss: 15.2025, Val Loss: 7.6934, Val Accuracy: 0.7370
# Epoch [3/100], Train Loss: 6.2089, Val Loss: 6.5647, Val Accuracy: 0.7444
# Epoch [4/100], Train Loss: 4.0852, Val Loss: 5.9900, Val Accuracy: 0.7600
# Epoch [5/100], Train Loss: 4.6786, Val Loss: 7.8839, Val Accuracy: 0.7219
# Epoch [6/100], Train Loss: 6.0561, Val Loss: 10.0964, Val Accuracy: 0.7370
# Epoch [7/100], Train Loss: 9.2653, Val Loss: 18.0017, Val Accuracy: 0.6537
# Epoch [8/100], Train Loss: 49.7993, Val Loss: 56.7669, Val Accuracy: 0.6463
# Epoch [9/100], Train Loss: 62.2750, Val Loss: 51.9181, Val Accuracy: 0.6759
# Epoch [10/100], Train Loss: 19.4170, Val Loss: 42.4178, Val Accuracy: 0.6544
# Epoch [11/100], Train Loss: 9.0315, Val Loss: 14.3857, Val Accuracy: 0.7604
# Epoch [12/100], Train Loss: 6.9091, Val Loss: 11.7414, Val Accuracy: 0.7689
# Epoch [13/100], Train Loss: 6.5154, Val Loss: 19.1714, Val Accuracy: 0.7370
# Epoch [14/100], Train Loss: 4.5986, Val Loss: 12.3526, Val Accuracy: 0.7567
# Epoch [15/100], Train Loss: 3.8958, Val Loss: 8.4447, Val Accuracy: 0.8370
# Epoch [16/100], Train Loss: 4.1360, Val Loss: 9.1244, Val Accuracy: 0.8133
# Epoch [17/100], Train Loss: 2.6188, Val Loss: 9.2057, Val Accuracy: 0.8296
# Epoch [18/100], Train Loss: 3.1781, Val Loss: 12.5793, Val Accuracy: 0.7889
# Epoch [19/100], Train Loss: 9.1618, Val Loss: 18.9306, Val Accuracy: 0.7426
# Epoch [20/100], Train Loss: 5.8291, Val Loss: 16.4529, Val Accuracy: 0.7759
# Epoch [21/100], Train Loss: 3.8248, Val Loss: 15.8573, Val Accuracy: 0.7844
# Epoch [22/100], Train Loss: 9.8121, Val Loss: 28.6970, Val Accuracy: 0.7122
# Epoch [23/100], Train Loss: 32.5213, Val Loss: 170.2357, Val Accuracy: 0.5144
# Epoch [24/100], Train Loss: 35.4721, Val Loss: 49.7240, Val Accuracy: 0.7170
# Epoch [25/100], Train Loss: 18.3755, Val Loss: 17.5085, Val Accuracy: 0.8570
# Epoch [26/100], Train Loss: 11.4306, Val Loss: 24.0764, Val Accuracy: 0.8141
# Epoch [27/100], Train Loss: 11.7927, Val Loss: 71.1923, Val Accuracy: 0.6704
# Epoch [28/100], Train Loss: 18.0246, Val Loss: 26.8836, Val Accuracy: 0.8233
# Epoch [29/100], Train Loss: 7.7327, Val Loss: 16.7483, Val Accuracy: 0.8441
# Epoch [30/100], Train Loss: 4.7340, Val Loss: 21.6165, Val Accuracy: 0.8026
# Epoch [31/100], Train Loss: 4.0932, Val Loss: 28.4492, Val Accuracy: 0.7589
# Epoch [32/100], Train Loss: 2.9584, Val Loss: 17.5854, Val Accuracy: 0.8352
# Epoch [33/100], Train Loss: 1.6183, Val Loss: 12.2374, Val Accuracy: 0.8552
# Epoch [34/100], Train Loss: 4.6510, Val Loss: 12.9312, Val Accuracy: 0.8511
# Epoch [35/100], Train Loss: 14.7416, Val Loss: 82.7717, Val Accuracy: 0.7211
# Epoch [36/100], Train Loss: 42.8306, Val Loss: 72.6998, Val Accuracy: 0.7481
# Epoch [37/100], Train Loss: 13.7040, Val Loss: 37.8527, Val Accuracy: 0.8019
# Epoch [38/100], Train Loss: 9.6440, Val Loss: 41.3677, Val Accuracy: 0.7989
# Epoch [39/100], Train Loss: 7.7175, Val Loss: 32.8426, Val Accuracy: 0.8311
# Epoch [40/100], Train Loss: 3.1389, Val Loss: 29.2773, Val Accuracy: 0.8141
# Epoch [41/100], Train Loss: 2.1792, Val Loss: 14.8894, Val Accuracy: 0.8885
# Epoch [42/100], Train Loss: 1.3019, Val Loss: 14.0450, Val Accuracy: 0.8670
# Epoch [43/100], Train Loss: 2.3689, Val Loss: 17.0473, Val Accuracy: 0.8900
# Epoch [44/100], Train Loss: 3.6184, Val Loss: 12.0328, Val Accuracy: 0.9026
# Epoch [45/100], Train Loss: 2.6385, Val Loss: 42.7419, Val Accuracy: 0.7604
# Epoch [46/100], Train Loss: 1.9523, Val Loss: 17.0818, Val Accuracy: 0.8519
# Epoch [47/100], Train Loss: 2.4367, Val Loss: 20.3681, Val Accuracy: 0.8552
# Epoch [48/100], Train Loss: 2.4560, Val Loss: 36.6071, Val Accuracy: 0.7974
# Epoch [49/100], Train Loss: 2.6170, Val Loss: 14.5735, Val Accuracy: 0.8863
# Epoch [50/100], Train Loss: 4.8218, Val Loss: 16.6021, Val Accuracy: 0.8719
# Epoch [51/100], Train Loss: 1.3914, Val Loss: 13.9249, Val Accuracy: 0.8856
# Epoch [52/100], Train Loss: 3.0752, Val Loss: 163.3431, Val Accuracy: 0.6156
# Epoch [53/100], Train Loss: 3.9668, Val Loss: 19.6601, Val Accuracy: 0.8615
# Epoch [54/100], Train Loss: 2.7296, Val Loss: 360.1330, Val Accuracy: 0.5878
# Epoch [55/100], Train Loss: 10.3717, Val Loss: 43.6210, Val Accuracy: 0.8044
# Epoch [56/100], Train Loss: 55.1157, Val Loss: 70.7234, Val Accuracy: 0.7904
# Epoch [57/100], Train Loss: 17.1179, Val Loss: 143.3833, Val Accuracy: 0.6593
# Epoch [58/100], Train Loss: 21.8788, Val Loss: 99.0534, Val Accuracy: 0.7607
# Epoch [59/100], Train Loss: 10.1293, Val Loss: 53.9210, Val Accuracy: 0.7896
# Epoch [60/100], Train Loss: 4.3085, Val Loss: 25.0191, Val Accuracy: 0.8878
# Epoch [61/100], Train Loss: 2.5883, Val Loss: 41.2460, Val Accuracy: 0.8670
# Epoch [62/100], Train Loss: 23.2069, Val Loss: 69.1966, Val Accuracy: 0.7944
# Epoch [63/100], Train Loss: 11.8962, Val Loss: 41.3185, Val Accuracy: 0.8389
# Epoch [64/100], Train Loss: 2.4566, Val Loss: 23.5349, Val Accuracy: 0.8785
# Epoch [65/100], Train Loss: 1.7645, Val Loss: 46.3942, Val Accuracy: 0.7956
# Epoch [66/100], Train Loss: 0.8787, Val Loss: 17.0997, Val Accuracy: 0.9148
# Epoch [67/100], Train Loss: 1.5833, Val Loss: 34.2590, Val Accuracy: 0.8752
# Epoch [68/100], Train Loss: 1.6914, Val Loss: 16.9895, Val Accuracy: 0.9041
# Epoch [69/100], Train Loss: 5.1735, Val Loss: 25.4069, Val Accuracy: 0.8648
# Epoch [70/100], Train Loss: 2.6960, Val Loss: 67.2667, Val Accuracy: 0.8000
# Epoch [71/100], Train Loss: 4.1172, Val Loss: 23.1011, Val Accuracy: 0.9000
# Epoch [72/100], Train Loss: 1.5371, Val Loss: 15.1481, Val Accuracy: 0.9185
# Epoch [73/100], Train Loss: 0.8719, Val Loss: 26.3608, Val Accuracy: 0.8667
# Epoch [74/100], Train Loss: 4.4526, Val Loss: 44.6629, Val Accuracy: 0.8219
# Epoch [75/100], Train Loss: 1.5570, Val Loss: 25.9518, Val Accuracy: 0.8552
# Epoch [76/100], Train Loss: 0.8774, Val Loss: 59.3855, Val Accuracy: 0.8022
# Epoch [77/100], Train Loss: 1.0626, Val Loss: 14.7555, Val Accuracy: 0.9167
# Epoch [78/100], Train Loss: 1.6171, Val Loss: 62.3010, Val Accuracy: 0.8167
# Epoch [79/100], Train Loss: 4.4468, Val Loss: 89.5918, Val Accuracy: 0.7485
# Epoch [80/100], Train Loss: 6.7241, Val Loss: 31.6792, Val Accuracy: 0.8733
# Epoch [81/100], Train Loss: 3.8964, Val Loss: 25.0781, Val Accuracy: 0.8393
# Epoch [82/100], Train Loss: 5.6089, Val Loss: 55.1642, Val Accuracy: 0.8230
# Epoch [83/100], Train Loss: 105.1596, Val Loss: 237.5636, Val Accuracy: 0.7085
# Epoch [84/100], Train Loss: 19.7556, Val Loss: 43.7001, Val Accuracy: 0.8207
# Epoch [85/100], Train Loss: 5.3194, Val Loss: 31.7011, Val Accuracy: 0.9030
# Epoch [86/100], Train Loss: 1.6784, Val Loss: 17.5934, Val Accuracy: 0.9263
# Epoch [87/100], Train Loss: 1.0497, Val Loss: 21.7100, Val Accuracy: 0.9152
# Epoch [88/100], Train Loss: 0.9220, Val Loss: 19.7060, Val Accuracy: 0.9144
# Epoch [89/100], Train Loss: 0.7412, Val Loss: 19.9346, Val Accuracy: 0.9137
# Epoch [90/100], Train Loss: 0.6961, Val Loss: 18.3867, Val Accuracy: 0.9222
# Epoch [91/100], Train Loss: 0.5318, Val Loss: 23.4079, Val Accuracy: 0.9074
# Epoch [92/100], Train Loss: 0.6369, Val Loss: 20.7215, Val Accuracy: 0.9211
# Epoch [93/100], Train Loss: 0.9905, Val Loss: 18.4766, Val Accuracy: 0.9211
# Epoch [94/100], Train Loss: 2.1726, Val Loss: 39.6761, Val Accuracy: 0.8615
# Epoch [95/100], Train Loss: 1.3813, Val Loss: 20.0165, Val Accuracy: 0.9104
# Epoch [96/100], Train Loss: 1.8806, Val Loss: 23.2493, Val Accuracy: 0.9130
# Epoch [97/100], Train Loss: 0.6461, Val Loss: 18.0400, Val Accuracy: 0.9185
# Epoch [98/100], Train Loss: 0.9533, Val Loss: 60.4197, Val Accuracy: 0.8363
# Epoch [99/100], Train Loss: 1.9522, Val Loss: 23.8543, Val Accuracy: 0.8993
# Epoch [100/100], Train Loss: 1.4684, Val Loss: 30.3462, Val Accuracy: 0.8893
# Metrics for window size 13x13: {'OA': 0.893875778196033, 'AA': 0.8885977211002597, 'Kappa': 0.853518447863063}
